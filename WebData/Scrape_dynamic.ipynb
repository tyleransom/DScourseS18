# %% [markdown]
# # Scraping JavaScript data ("dynamic webpages")
# ### by [Jason DeBacker](http://jasondebacker.com), October 2017 (with thanks to [Adam Rennhoff](http://mtweb.mtsu.edu/rennhoff/) )
#
# This notebook provides a tutorial and examples showing how to scrape webpages with JavaScript data.
#
# ## Example: scrape the store locations for Walgreens pharmacies.
#
# Sometimes the webpage will be more complicated. As an example, suppose that I want to scrape store locations of Walgreens pharmacies.
#
# ![Walgreen Locations Screenshot](files/images/WalgreenLocations.png)
#
# Notice that I am searching for stores near zip code 29205 but this fact is NOT displayed in the url, which is `https://www.walgreens.com/storelocator/find.jsp`. In other words, the zip code is not part of the url so it would not be possible to loop over different locations the way we did with the Wikipedia pages.
#
# What can we do? Lets look at the request that is being sent to Walgreens.com to see if we can mimic the request that is being sent. To do this, we need to use the "Inspect" tool to look at the network data ("XHR") (Note that the format of the inspect tool will vary depending on the internet browser you are using - in the screenshots below, I'm using Safari Version 11.0):
#
# ![Walgreen Inspect Screenshot](files/images/WalgreensInspect.png)
#
# This will take some trial and error but you can see a list of requests under "Resources" and then "XHR". I have clicked on the second search result in the list.  Notice that this is showing the address of the first result (4467 DEVINE ST). This tells me that this is the request I want to mimic.
#
#
# In order to figure out the format of my request, I need to click on the drop down menu that says "Response" and select "Request" from this menu.  Then click on the "show details sidebar" icon to show details of the request.
#
# ![Walgreen Request Screenshot](files/images/RequestType.png)
#
# The "request payload" in this case is: `{"q":" Columbia, SC 29205","r":"50","lat":33.9900337,"lng":-80.99815760000001,"requestType":"locator","s":"15","p":"1"}`
#
# The request payload tells us what we need to send to the URL so that they return the information we want
#
# There are three things from the show details that we'll also need: "Location", "Request and Response", and "Request Payload"
#
# * "Location" will tell us the URL that we make our request to
# * "Request and Responses" will tell us the method (POST)
# * "Request Headers" will tell us the information that needs to be in the header of our request -- in the Wikipedia example, we had to send a "User-Agent" so that it looked like we were coming from a web browser like Chrome or Firefox
#
# Let's try to make that request using the requests library in Python

# %%
import requests
import json

url = 'https://customersearch.walgreens.com/storelocator/v1/stores/search' # from Headers Request URL

# Request payloads
pay = {
    "q":" Columbia, SC 29205",
    "r":"500","lat":33.9900337,
    "lng":-80.99815760000001,
    "requestType":"locator",
    "s":"15",
    "p":"1"
}


# Request headers
heads = {
    "Accept" : "application/json, text/plain, */*",
    "Accept-Encoding" : "gzip, deflate, br",
    "Accept-Language" : "en-US,en;q=0.8",
    "Connection" : "keep-alive",
    "Content-Length" : "105",
    "Content-Type" : "application/json;charset=UTF-8",
    "Host" : "customersearch.walgreens.com",
    "Origin" : "https://www.walgreens.com",
    "Referer" : "https://www.walgreens.com/storelocator/find.jsp?tab=store+locator&requestType=locator",
    "User-Agent" : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/604.1.38 (KHTML, like Gecko) Version/11.0 Safari/604.1.38"  
}

# Making our POST request using the headers and payload
response = requests.post(url, data = json.dumps(pay), headers = heads)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# A response code of 200 means that the request was properly sent and received. Success!
#
# Our next step is to get the data in a usable format by using the JSON data and remebering the format of the response we receive (from the "Preview" tab).

# %%
data = response.json() # our requested information is now saved as JSON data
len(data)
# data.keys()
# data['filter']
# Out:
# 3

# %% [markdown]
# We can only see the first two elements in the image above but our JSON data has three elements: "filter", "results", and "summary". The "results" key contains the information we really want.

# %%
results = data['results']
len(results)
results
# Out:
# [{'distance': '1.2',
#   'latitude': '33.992543',
#   'longitude': '-80.977481',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '4467 DEVINE ST',
#     'zip': '29205'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '11PM',
#    'pharmacyOpenTime': '7AM',
#    'phone': [{'areaCode': '803', 'number': '7872527 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 't4hr', 'name': 'Store Open 24 hours'},
#     {'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '6136',
#    'storeOpenTime': '12AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-4467+devine+st-columbia-sc-29205/id=6136'},
#  {'distance': '1.23',
#   'latitude': '33.99815572',
#   'longitude': '-81.01721273',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '1941 BLOSSOM ST',
#     'zip': '29205'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '2121015 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '11433',
#    'storeOpenTime': '7AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1941+blossom+st-columbia-sc-29205/id=11433'},
#  {'distance': '2.11',
#   'latitude': '34.01962393',
#   'longitude': '-80.98935704',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '3501 FOREST DR',
#     'zip': '29204'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7434373 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '6262',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-3501+forest+dr-columbia-sc-29204/id=6262'},
#  {'distance': '4.57',
#   'latitude': '33.95574358',
#   'longitude': '-80.93004421',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '7801 GARNERS FERRY RD',
#     'zip': '29209'},
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '6477638 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '11379',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-7801+garners+ferry+rd-columbia-sc-29209/id=11379'},
#  {'distance': '4.67',
#   'latitude': '33.9712',
#   'longitude': '-81.076419',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'WEST COLUMBIA',
#     'state': 'SC',
#     'street': '1537 CHARLESTON HWY',
#     'zip': '29169'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7963392 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '10230',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1537+charleston+hwy-west+columbia-sc-29169/id=10230'},
#  {'distance': '5.62',
#   'latitude': '33.983999',
#   'longitude': '-81.095999',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'WEST COLUMBIA',
#     'state': 'SC',
#     'street': '2224 AUGUSTA RD',
#     'zip': '29169'},
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7913676 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '6137',
#    'storeOpenTime': '7AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-2224+augusta+rd-west+columbia-sc-29169/id=6137'},
#  {'distance': '7.48',
#   'latitude': '34.05012611',
#   'longitude': '-81.10671602',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '1223 SAINT ANDREWS RD',
#     'zip': '29210'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7315120 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '9487',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1223+saint+andrews+rd-columbia-sc-29210/id=9487'},
#  {'distance': '8.05',
#   'latitude': '34.0905866',
#   'longitude': '-80.92732406',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '9001 TWO NOTCH RD',
#     'zip': '29223'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '4193664 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '12478',
#    'storeOpenTime': '7AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-9001+two+notch+rd-columbia-sc-29223/id=12478'},
#  {'distance': '10.33',
#   'latitude': '33.94488855',
#   'longitude': '-81.16991191',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'WEST COLUMBIA',
#     'state': 'SC',
#     'street': '1010 OLD BARNWELL RD',
#     'zip': '29170'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '3580612 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '1073',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1010+old+barnwell+rd-west+columbia-sc-29170/id=1073'},
#  {'distance': '10.95',
#   'latitude': '34.14019196',
#   'longitude': '-80.93721661',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '2725 CLEMSON RD',
#     'zip': '29229'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '6784887 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '10228',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-2725+clemson+rd-columbia-sc-29229/id=10228'},
#  {'distance': '11.75',
#   'latitude': '34.00556364',
#   'longitude': '-81.20244564',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'LEXINGTON',
#     'state': 'SC',
#     'street': '5220 SUNSET BLVD',
#     'zip': '29072'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '3580318 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '12512',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-5220+sunset+blvd-lexington-sc-29072/id=12512'},
#  {'distance': '11.9',
#   'latitude': '34.09718708',
#   'longitude': '-81.16093461',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'IRMO',
#     'state': 'SC',
#     'street': '7412 BROAD RIVER RD',
#     'zip': '29063'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7493046 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '9805',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-7412+broad+river+rd-irmo-sc-29063/id=9805'},
#  {'distance': '12.02',
#   'latitude': '34.13197323',
#   'longitude': '-80.87677575',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '175 FORUM DR',
#     'zip': '29229'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '6997067 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '10227',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-175+forum+dr-columbia-sc-29229/id=10227'},
#  {'distance': '12.03',
#   'latitude': '34.14826121',
#   'longitude': '-80.91050713',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '4520 HARD SCRABBLE RD',
#     'zip': '29229'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '4197507 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '12677',
#    'storeOpenTime': '7AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-4520+hard+scrabble+rd-columbia-sc-29229/id=12677'},
#  {'distance': '12.81',
#   'latitude': '34.08330686',
#   'longitude': '-81.19152445',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'COLUMBIA',
#     'state': 'SC',
#     'street': '1532 LAKE MURRAY BLVD',
#     'zip': '29212'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7321975 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '11851',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1532+lake+murray+blvd-columbia-sc-29212/id=11851'},
#  {'distance': '14.08',
#   'latitude': '33.90759703',
#   'longitude': '-81.22270974',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'LEXINGTON',
#     'state': 'SC',
#     'street': '1903 S LAKE DR',
#     'zip': '29073'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '3561001 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '11362',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1903+s+lake+dr-lexington-sc-29073/id=11362'},
#  {'distance': '14.16',
#   'latitude': '33.9861201',
#   'longitude': '-81.24534419',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'LEXINGTON',
#     'state': 'SC',
#     'street': '423 W MAIN ST',
#     'zip': '29072'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '12AM',
#    'pharmacyOpenTime': '12AM',
#    'phone': [{'areaCode': '803', 'number': '9573071 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 't4hr', 'name': 'Store Open 24 hours'},
#     {'code': 't4hr_rx', 'name': 'Pharmacy Open 24 hours'},
#     {'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '7399',
#    'storeOpenTime': '12AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-423+w+main+st-lexington-sc-29072/id=7399'},
#  {'distance': '16.33',
#   'latitude': '34.1247176',
#   'longitude': '-81.23265937',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'IRMO',
#     'state': 'SC',
#     'street': '1251 DUTCH FORK RD',
#     'zip': '29063'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '7497099 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '10226',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1251+dutch+fork+rd-irmo-sc-29063/id=10226'},
#  {'distance': '29.51',
#   'latitude': '34.27145685',
#   'longitude': '-80.61015466',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'CAMDEN',
#     'state': 'SC',
#     'street': '2407 BROAD ST',
#     'zip': '29020'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '4242510 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '9232',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-2407+broad+st-camden-sc-29020/id=9232'},
#  {'distance': '31.05',
#   'latitude': '33.91029303',
#   'longitude': '-81.5312063',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'BATESBURG',
#     'state': 'SC',
#     'street': '127 W COLUMBIA AVE',
#     'zip': '29006'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '5322586 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '12163',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-127+w+columbia+ave-batesburg-sc-29006/id=12163'},
#  {'distance': '33.9',
#   'latitude': '33.513195',
#   'longitude': '-80.859522',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'ORANGEBURG',
#     'state': 'SC',
#     'street': '1290 CHESTNUT ST',
#     'zip': '29115'},
#    'emergencyCode': '0',
#    'pharmacyCloseTime': '8PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '5316115 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '7506',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1290+chestnut+st-orangeburg-sc-29115/id=7506'},
#  {'distance': '35.63',
#   'latitude': '33.48662115',
#   'longitude': '-80.86383691',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'ORANGEBURG',
#     'state': 'SC',
#     'street': '1106 JOHN C CALHOUN DR',
#     'zip': '29115'},
#    'pharmacyCloseTime': '8PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '5312079 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '9879',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1106+john+c+calhoun+dr-orangeburg-sc-29115/id=9879'},
#  {'distance': '35.94',
#   'latitude': '33.94519706',
#   'longitude': '-80.37334259',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'SUMTER',
#     'state': 'SC',
#     'street': '1000 BROAD ST',
#     'zip': '29150'},
#    'pharmacyCloseTime': '12AM',
#    'pharmacyOpenTime': '12AM',
#    'phone': [{'areaCode': '803', 'number': '7737302 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 't4hr', 'name': 'Store Open 24 hours'},
#     {'code': 't4hr_rx', 'name': 'Pharmacy Open 24 hours'},
#     {'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '12AM',
#    'storeNumber': '6074',
#    'storeOpenTime': '12AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1000+broad+st-sumter-sc-29150/id=6074'},
#  {'distance': '36.04',
#   'latitude': '33.90408029',
#   'longitude': '-80.37805481',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'SUMTER',
#     'state': 'SC',
#     'street': '1990 MCCRAYS MILL RD',
#     'zip': '29150'},
#    'pharmacyCloseTime': '10PM',
#    'pharmacyOpenTime': '8AM',
#    'phone': [{'areaCode': '803', 'number': '9340847 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '9276',
#    'storeOpenTime': '7AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-1990+mccrays+mill+rd-sumter-sc-29150/id=9276'},
#  {'distance': '38.23',
#   'latitude': '33.92465291',
#   'longitude': '-80.33573928',
#   'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#   'store': {'address': {'city': 'SUMTER',
#     'state': 'SC',
#     'street': '201 N LAFAYETTE DR',
#     'zip': '29150'},
#    'pharmacyCloseTime': '9PM',
#    'pharmacyOpenTime': '9AM',
#    'phone': [{'areaCode': '803', 'number': '7734959 ', 'type': 'store'}],
#    'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#     {'code': 'imn', 'name': 'Immunizations'},
#     {'code': 'fs', 'name': 'Flu Shot'},
#     {'code': 'phi', 'name': 'One Hour Photo'},
#     {'code': 'rb', 'name': 'Redbox'}],
#    'storeBrand': 'Walgreens',
#    'storeCloseTime': '10PM',
#    'storeNumber': '11724',
#    'storeOpenTime': '8AM',
#    'storeType': '01',
#    'telePharmacyKiosk': False,
#    'timeZone': 'EA'},
#   'storeSeoUrl': '/locator/walgreens-201+n+lafayette+dr-sumter-sc-29150/id=11724'}]

# %% [markdown]
# This is data for 15 stores in our "results" variable. Go back and look at the code, notice that in the payload, we set a parameter 's' to equal 15
#
# Let's look at the results for the first store in the listings...

# %%
results[0]
# Out:
# {'distance': '1.2',
#  'latitude': '33.992543',
#  'longitude': '-80.977481',
#  'mapUrl': 'https://maps.googleapis.com/maps/api/staticmap?size=451x451&markers=icon:http://www.walgreens.com/images/gmap/markers/point_wag.png|shadow:true|33.9900337,-80.99815760000001&client=gme-walgreens&sensor=false',
#  'store': {'address': {'city': 'COLUMBIA',
#    'state': 'SC',
#    'street': '4467 DEVINE ST',
#    'zip': '29205'},
#   'emergencyCode': '0',
#   'pharmacyCloseTime': '11PM',
#   'pharmacyOpenTime': '7AM',
#   'phone': [{'areaCode': '803', 'number': '7872527 ', 'type': 'store'}],
#   'serviceIndicators': [{'code': 't4hr', 'name': 'Store Open 24 hours'},
#    {'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#    {'code': 'imn', 'name': 'Immunizations'},
#    {'code': 'fs', 'name': 'Flu Shot'},
#    {'code': 'phi', 'name': 'One Hour Photo'},
#    {'code': 'rb', 'name': 'Redbox'}],
#   'storeBrand': 'Walgreens',
#   'storeCloseTime': '12AM',
#   'storeNumber': '6136',
#   'storeOpenTime': '12AM',
#   'storeType': '01',
#   'telePharmacyKiosk': False,
#   'timeZone': 'EA'},
#  'storeSeoUrl': '/locator/walgreens-4467+devine+st-columbia-sc-29205/id=6136'}

# %% [markdown]
# It may be difficult to see in the output but most of the information we would want is contained in the 'store' element:

# %%
results[0]['store'] # first store in the list
# Out:
# {'address': {'city': 'COLUMBIA',
#   'state': 'SC',
#   'street': '4467 DEVINE ST',
#   'zip': '29205'},
#  'emergencyCode': '0',
#  'pharmacyCloseTime': '11PM',
#  'pharmacyOpenTime': '7AM',
#  'phone': [{'areaCode': '803', 'number': '7872527 ', 'type': 'store'}],
#  'serviceIndicators': [{'code': 't4hr', 'name': 'Store Open 24 hours'},
#   {'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#   {'code': 'imn', 'name': 'Immunizations'},
#   {'code': 'fs', 'name': 'Flu Shot'},
#   {'code': 'phi', 'name': 'One Hour Photo'},
#   {'code': 'rb', 'name': 'Redbox'}],
#  'storeBrand': 'Walgreens',
#  'storeCloseTime': '12AM',
#  'storeNumber': '6136',
#  'storeOpenTime': '12AM',
#  'storeType': '01',
#  'telePharmacyKiosk': False,
#  'timeZone': 'EA'}

# %%
results[1]['store'] # second store on the list
# Out:
# {'address': {'city': 'COLUMBIA',
#   'state': 'SC',
#   'street': '1941 BLOSSOM ST',
#   'zip': '29205'},
#  'emergencyCode': '0',
#  'pharmacyCloseTime': '9PM',
#  'pharmacyOpenTime': '9AM',
#  'phone': [{'areaCode': '803', 'number': '2121015 ', 'type': 'store'}],
#  'serviceIndicators': [{'code': 'dt', 'name': 'Drive-Thru Pharmacy'},
#   {'code': 'imn', 'name': 'Immunizations'},
#   {'code': 'fs', 'name': 'Flu Shot'},
#   {'code': 'phi', 'name': 'One Hour Photo'}],
#  'storeBrand': 'Walgreens',
#  'storeCloseTime': '10PM',
#  'storeNumber': '11433',
#  'storeOpenTime': '7AM',
#  'storeType': '01',
#  'telePharmacyKiosk': False,
#  'timeZone': 'EA'}

# %% [markdown]
# Suppose that for a research question, I am interested in knowing which Walgreens locations offer flu shots. After some exploration, I see that a "serviceIndicators" code of "fs" indicates that flu shots are offered at that location. We can loop through the 15 returned stores to print out a list of the stores that offer flu shots.

# %%
# Loop over 15 stores
for j in range(len(results)):
    # For each store, loop over their serviceIndicators to find 'tc'
    for i in results[j]['store']['serviceIndicators']:
        if i['code'] == 'fs':
            print('The Walgreens at ' + str(results[j]['store']['address']['street']) + ' offers flu shots.')
# Out:
# The Walgreens at 4467 DEVINE ST offers flu shots.
# The Walgreens at 1941 BLOSSOM ST offers flu shots.
# The Walgreens at 3501 FOREST DR offers flu shots.
# The Walgreens at 7801 GARNERS FERRY RD offers flu shots.
# The Walgreens at 1537 CHARLESTON HWY offers flu shots.
# The Walgreens at 2224 AUGUSTA RD offers flu shots.
# The Walgreens at 1223 SAINT ANDREWS RD offers flu shots.
# The Walgreens at 9001 TWO NOTCH RD offers flu shots.
# The Walgreens at 1010 OLD BARNWELL RD offers flu shots.
# The Walgreens at 2725 CLEMSON RD offers flu shots.
# The Walgreens at 5220 SUNSET BLVD offers flu shots.
# The Walgreens at 7412 BROAD RIVER RD offers flu shots.
# The Walgreens at 175 FORUM DR offers flu shots.
# The Walgreens at 4520 HARD SCRABBLE RD offers flu shots.
# The Walgreens at 1532 LAKE MURRAY BLVD offers flu shots.
# The Walgreens at 1903 S LAKE DR offers flu shots.
# The Walgreens at 423 W MAIN ST offers flu shots.
# The Walgreens at 1251 DUTCH FORK RD offers flu shots.
# The Walgreens at 2407 BROAD ST offers flu shots.
# The Walgreens at 127 W COLUMBIA AVE offers flu shots.
# The Walgreens at 1290 CHESTNUT ST offers flu shots.
# The Walgreens at 1106 JOHN C CALHOUN DR offers flu shots.
# The Walgreens at 1000 BROAD ST offers flu shots.
# The Walgreens at 1990 MCCRAYS MILL RD offers flu shots.
# The Walgreens at 201 N LAFAYETTE DR offers flu shots.
